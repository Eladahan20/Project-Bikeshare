# %%
import pandas as pd

# %%
df = pd.read_csv('washington.csv')

# %%
df['Start Time'] = pd.to_datetime(df['Start Time'])
#Create columns for month, day and hour
df['Month'] = df['Start Time'].dt.month_name()
df['Day'] = df['Start Time'].dt.day_name()
df['Start Hour'] = df['Start Time'].dt.hour

# %%
df.head(10)
# Out:
#    Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0     1621326 2017-06-21 08:36:34  2017-06-21 08:44:43        489.066
# 1      482740 2017-03-11 10:40:00  2017-03-11 10:46:00        402.549
# 2     1330037 2017-05-30 01:02:59  2017-05-30 01:13:37        637.251
# 3      665458 2017-04-02 07:48:35  2017-04-02 08:19:03       1827.341
# 4     1481135 2017-06-10 08:36:28  2017-06-10 09:02:17       1549.427
# 5     1148202 2017-05-14 07:18:18  2017-05-14 07:24:56        398.000
# 6     1594275 2017-06-19 08:41:43  2017-06-19 09:00:08       1105.429
# 7     1601832 2017-06-20 05:54:42  2017-06-20 06:05:18        636.218
# 8      574182 2017-03-24 20:37:00  2017-03-24 20:42:00        328.530
# 9      327058 2017-02-20 21:12:00  2017-02-20 21:31:00       1188.090
#
#                                  Start Station  \
# 0                         14th & Belmont St NW
# 1                   Yuma St & Tenley Circle NW
# 2               17th St & Massachusetts Ave NW
# ...

# %%
df = df.loc[df['Month'] == 'January']

# %%
df = df.loc[df['Day'] == 'Monday']

# %%
mc_prec = df['Start Hour'].value_counts(normalize=True, ascending=False)[17]

# %%
mc_prec
# Out:
# 0.13141809290953546

# %%
df['Start Station'].mode()[0]
# Out:
# 'Columbus Circle / Union Station'

# %%
df['End Station'].mode()[0]
# Out:
# 'Columbus Circle / Union Station'

# %%
' & '.join(df.groupby(['Start Station', 'End Station']).size().sort_values(ascending=False).idxmax())
# Out:
# '1st & D St SE & 1st & K St SE'

# %%
df
# Out:
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 35           34042 2017-01-09 12:29:00  2017-01-09 12:48:00       1138.896
# 210         117386 2017-01-23 09:42:00  2017-01-23 10:03:00       1267.685
# 295          77719 2017-01-16 18:39:00  2017-01-16 18:55:00        933.324
# 357         118393 2017-01-23 18:02:00  2017-01-23 18:17:00        866.366
# 717          77760 2017-01-16 18:46:00  2017-01-16 18:52:00        365.124
# ...            ...                 ...                  ...            ...
# 299325      162817 2017-01-30 08:48:00  2017-01-30 08:55:00        442.784
# 299578      166546 2017-01-30 20:00:00  2017-01-30 20:08:00        477.398
# 299592       76204 2017-01-16 14:39:00  2017-01-16 14:51:00        738.871
# 299751        5331 2017-01-02 18:57:00  2017-01-02 19:03:00        304.731
# 299992       32912 2017-01-09 08:11:00  2017-01-09 08:14:00        191.131
#
#                                             Start Station  \
# ...

# %%
df['Start Hour'].value_counts(normalize=True, ascending=False)[17]
# Out:
# 0.13141809290953546
